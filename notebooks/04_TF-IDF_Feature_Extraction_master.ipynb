# %%
# Loading the preprocessed dataset for validation
import pandas as pd

df = pd.read_csv("../data/processed/uganda_fake_news_preprocessed_master_dataset.csv")

df.head()
# Out:
#             id                                               text label  \
# 0  UG_TRUE_001  The Ministry of Health confirms no outbreak of...  TRUE
# 1  UG_FAKE_001  Drinking hot water every 15 minutes kills COVI...  FAKE
# 2  UG_FAKE_002  Government has approved free electricity for a...  FAKE
# 3  UG_TRUE_002  Parliament passes new amendment to the Nationa...  TRUE
# 4  UG_TRUE_003  Museveni alisema hakuna lockdown tena nchini U...  TRUE
#
#           source platform_type language date_collected  text_length  \
# 0  Daily Monitor  News Website  English     2025-01-10           11
# 1    AfricaCheck    Fact-Check  English     2025-01-10           12
# 2      PesaCheck    Fact-Check  English     2025-01-11           11
# 3     New Vision  News Website  English     2025-01-11           10
# 4     BBC Africa  News Website    Mixed     2025-01-12            7
#
#                                           clean_text  label_encoded
# ...

# %%
# verify the required columns are present
df.columns
# Out:
# Index(['id', 'text', 'label', 'source', 'platform_type', 'language',
#        'date_collected', 'text_length', 'clean_text', 'label_encoded'],
#       dtype='object')

# %%
# splitting the dataset into training and testing sets

from sklearn.model_selection import train_test_split

X = df['clean_text']
y = df['label_encoded']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
#apply TF-IDF vectorization to convert text data into numerical features
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1,2),
    min_df=2
)

X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
# Save the TF-IDF vectorizer for future use in model training and inference
import joblib

joblib.dump(tfidf, "../models/tfidf_vectorizer.pkl")
# Out:
# ['../models/tfidf_vectorizer.pkl']
